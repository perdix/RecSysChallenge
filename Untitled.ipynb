# %%
#Test

# %%
from collections import Counter
import requests
s = requests.Session()
import base64
encoded = base64.b64encode(b'8f61bd6e36ef4b4e9607a0d20288be1c:3fefca6753a440daaf5395da6554af7e').decode("utf-8") 
encoded
# Out:
# 'OGY2MWJkNmUzNmVmNGI0ZTk2MDdhMGQyMDI4OGJlMWM6M2ZlZmNhNjc1M2E0NDBkYWFmNTM5NWRhNjU1NGFmN2U='

# %%
#Get Token
headers = {
    'Accept': 'application/json',
    'Authorization': 'Basic ' + encoded
}
data = {
    'grant_type': 'client_credentials'
}
response = s.post('https://accounts.spotify.com/api/token', headers=headers, data=data)
response.json()
# Out:
# {'access_token': 'BQD5F_JY2bXmsUvI23WLEz06DupCrPuWfgWdFatprHftva9IOUE9XkO1E4j_tKPhTmqEtTtOla8lXnUUc38J9w',
#  'expires_in': 3600,
#  'token_type': 'Bearer'}

# %%
url_track = 'https://api.spotify.com/v1/tracks/?ids='
url_album = 'https://api.spotify.com/v1/albums/?ids='
headers = {
    'Accept': 'application/json',
    'Authorization': 'Bearer BQAjqjs0FINDrw467dCZmyeLkPMPRyr5vCqtXCZ1bV_LHhbBGpnSIAdgUa4X9moI4FPfE9JL0NH-hykplt3VQw'
}

# %%
chunk = ['2quNpty9mjNT9zy2kxmFXT','72WZtWs6V7uu3aMgMmEkYe','6AErh7UIjSTJPxR87QE7ok','282fVpiaACFaoMmphoPHJz']

# %%
response = s.get(url_track + ','.join(chunk), headers=headers)

# %%
tracks = response.json()['tracks']
tracks
# Out:
# [{'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6kkQkBRrPcQGUN8g2grxwb'},
#      'href': 'https://api.spotify.com/v1/artists/6kkQkBRrPcQGUN8g2grxwb',
#      'id': '6kkQkBRrPcQGUN8g2grxwb',
#      'name': 'Varry Brava',
#      'type': 'artist',
#      'uri': 'spotify:artist:6kkQkBRrPcQGUN8g2grxwb'}],
#    'available_markets': ['AD',
#     'AR',
#     'AT',
#     'AU',
#     'BE',
#     'BG',
#     'BO',
#     'BR',
#     'CA',
#     'CH',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DE',
#     'DK',
#     'DO',
#     'EC',
#     'EE',
#     'ES',
#     'FI',
#     'FR',
#     'GB',
#     'GR',
#     'GT',
#     'HK',
#     'HN',
#     'HU',
#     'ID',
#     'IE',
#     'IS',
#     'IT',
#     'JP',
#     'LI',
#     'LT',
#     'LU',
#     'LV',
#     'MC',
#     'MT',
#     'MX',
#     'MY',
#     'NI',
#     'NL',
#     'NO',
#     'NZ',
#     'PA',
#     'PE',
#     'PH',
#     'PL',
# ...

# %%
for track in tracks:
    print(track['album']['id'])
# Out:
# 5dyJ86uOz7SDzKSyhG5JCQ
# 0c78nsgqX6VfniSNWIxwoD
# 4sSH3HIsDv0U6VLZi6MDQ0
# 08V9lzekb75G85aTBCexdU

# %%
chunk = ['5dyJ86uOz7SDzKSyhG5JCQ','0c78nsgqX6VfniSNWIxwoD']

# %%
response = s.get(url_album + ','.join(chunk), headers=headers)

# %%
albums = response.json()['albums']
albums
# Out:
# [{'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6kkQkBRrPcQGUN8g2grxwb'},
#     'href': 'https://api.spotify.com/v1/artists/6kkQkBRrPcQGUN8g2grxwb',
#     'id': '6kkQkBRrPcQGUN8g2grxwb',
#     'name': 'Varry Brava',
#     'type': 'artist',
#     'uri': 'spotify:artist:6kkQkBRrPcQGUN8g2grxwb'}],
#   'available_markets': ['AD',
#    'AR',
#    'AT',
#    'AU',
#    'BE',
#    'BG',
#    'BO',
#    'BR',
#    'CA',
#    'CH',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DE',
#    'DK',
#    'DO',
#    'EC',
#    'EE',
#    'ES',
#    'FI',
#    'FR',
#    'GB',
#    'GR',
#    'GT',
#    'HK',
#    'HN',
#    'HU',
#    'ID',
#    'IE',
#    'IS',
#    'IT',
#    'JP',
#    'LI',
#    'LT',
#    'LU',
#    'LV',
#    'MC',
#    'MT',
#    'MX',
#    'MY',
#    'NI',
#    'NL',
#    'NO',
#    'NZ',
#    'PA',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'PY',
#    'SE',
#    'SG',
#    'SK',
#    'SV',
# ...

# %%
for album in albums:
    test = [i['id'] for i in album['tracks']['items']]
    print(test)
    print('--')
# Out:
# ['2quNpty9mjNT9zy2kxmFXT']
# --
# ['1dv3ePjze9tPq2pk8eWJdR', '3ZdZJ6iwE2o24pv6cGsCFG', '5Nj1RxAFkBsNocIJnWPkCz', '0Z7CezkdxWVKLFO4mLYcs3', '73d5kMQtyS8RhbVxElFZE6', '1O9YolbGxiImSIL83fk33x', '17CyJTMzvygZggYVVaZMH9', '5L7SFfCFs60ciETLOyyfru', '72WZtWs6V7uu3aMgMmEkYe']
# --

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
# Read data and create training and test sets
plays = pd.read_csv("data/ir2017.csv")

plays_train = pd.DataFrame()
plays_test = pd.DataFrame()

users = plays.groupby('user')
for i, user in users:
    train, test = train_test_split(user, test_size = 0.1)
    plays_train = plays_train.append(train)
    plays_test = plays_test.append(test)
